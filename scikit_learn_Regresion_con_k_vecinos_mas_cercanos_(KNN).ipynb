# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisAFD1/scikit_learn_tools/blob/main/scikit_learn_Regresion_con_k_vecinos_mas_cercanos_(KNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error


data = load_diabetes()


print(data.data.shape)
print(data.target.shape)
# Out:
# (442, 10)
# (442,)

# %%
data.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
print(data.data)
# Out:
# [[ 0.03807591  0.05068012  0.06169621 ... -0.00259226  0.01990749
#   -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 ... -0.03949338 -0.06833155
#   -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 ... -0.00259226  0.00286131
#   -0.02593034]
#  ...
#  [ 0.04170844  0.05068012 -0.01590626 ... -0.01107952 -0.04688253
#    0.01549073]
#  [-0.04547248 -0.04464164  0.03906215 ...  0.02655962  0.04452873
#   -0.02593034]
#  [-0.04547248 -0.04464164 -0.0730303  ... -0.03949338 -0.00422151
#    0.00306441]]

# %%
data.target
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(data.data, data.target)


print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (331, 10)
# (111, 10)
# (331,)
# (111,)

# %%
clf = KNeighborsRegressor()
clf.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = clf.predict(x_test)


df_y_test = pd.DataFrame(y_test, columns=['y_test'])
df_y_pred = pd.DataFrame(y_pred, columns=['y_pred'])
pd.concat([df_y_test, df_y_pred], axis=1)
# Out:
#      y_test  y_pred
# 0      60.0   128.6
# 1      91.0   173.0
# 2     321.0   257.6
# 3      70.0   160.2
# 4     138.0    67.0
# ..      ...     ...
# 106   111.0   125.2
# 107   161.0   177.4
# 108    97.0   115.4
# 109   179.0   153.8
# 110   129.0   158.2
#
# [111 rows x 2 columns]

# %%
plt.plot(y_test)
plt.plot(y_pred)
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.legend(['y_test', 'predicciones'])
plt.show()

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 4008.6032432432435
